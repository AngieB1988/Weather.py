# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import scipy.stats as st

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "C:\\Users\\Angiescomputer\\Desktop\\API_practice\\cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 619

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Set base url and units variables, and combine them to get the query url
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# Create empty lists to store the data for each field
city_id_list = []
city_name_list = []
country_list = []
lng_list = []
lat_list = []
temp_list = []
humidity_list = []
clouds_list = []
wind_speed_list = []

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Convert the data into a dataframe
cities_df = pd.DataFrame({"City ID": city_id_list, "City": city_name_list, "Country": country_list, "Lat": lat_list, "Lng": lng_list,
                         "Temperature": temp_list, "Humidity": humidity_list, "Clouds": clouds_list,
                         "Wind Speed": wind_speed_list})
cities_df.head()
# Out:
#    City ID          City Country      Lat       Lng  Temperature  Humidity  \
# 0  1246294         Galle      LK   6.0367   80.2170        82.26        84
# 1  1787599        Xingyi      CN  24.1877  102.8170        63.23        58
# 2  1218420         Seydi      TM  39.4816   62.9137        66.06        40
# 3  4032243         Vaini      TO -21.2000 -175.2000        77.16        61
# 4   650769  Kristinestad      FI  62.2743   21.3760        41.68        81
#
#    Clouds  Wind Speed
# 0     100       17.38
# 1     100        0.78
# 2       3        6.08
# 3      40        6.91
# 4     100       15.19

# %%
# Loop through cities
for city in cities:
    
    # Get the JSON response from the OpenWeather API
    response_json = requests.get(query_url + city).json()
    
    # Start the error handling
    # Retrieve the items for each field and append them to the empty lists  
    try:
        
        city_id = response_json['id']
        city_id_list.append(city_id)
            
        city_name = response_json['name']
        city_name_list.append(city_name)
        
        country_name = response_json['sys']['country']
        country_list.append(country_name)

        lng = response_json['coord']['lon']
        lng_list.append(lng)

        lat = response_json['coord']['lat']
        lat_list.append(lat)

        temp = response_json['main']['temp']
        temp_list.append(temp)

        humidity = response_json['main']['humidity']
        humidity_list.append(humidity)

        clouds = response_json['clouds']['all']
        clouds_list.append(clouds)

        wind_speed = response_json['wind']['speed']
        wind_speed_list.append(wind_speed)
    
        print(f"City Name: {city}, City ID: {city_id}")
    
    # Print error message and move on to the next city if there is an error
    except:
        
        print("That record does not exist, searching for next record...")
# Out:
# City Name: galle, City ID: 1246294
# City Name: xingyi, City ID: 1787599
# City Name: seydi, City ID: 1218420
# City Name: vaini, City ID: 4032243
# City Name: kristiinankaupunki, City ID: 650769
# City Name: ushuaia, City ID: 3833367
# City Name: ewa beach, City ID: 5855051
# City Name: tumen, City ID: 2034340
# City Name: bonavista, City ID: 5905393
# City Name: atuona, City ID: 4020109
# City Name: lumby, City ID: 6061958
# City Name: namibe, City ID: 3347019
# City Name: bethel, City ID: 5282297
# City Name: tuktoyaktuk, City ID: 6170031
# City Name: mataura, City ID: 6201424
# City Name: bredasdorp, City ID: 1015776
# City Name: souillac, City ID: 933995
# That record does not exist, searching for next record...
# That record does not exist, searching for next record...
# City Name: port lincoln, City ID: 2063036
# City Name: ponta do sol, City ID: 2264557
# City Name: correntina, City ID: 3465373
# City Name: puerto escondido, City ID: 3520994
# City Name: tambopata, City ID: 3927942
# City Name: saint george, City ID: 5546220
# City Name: rikitea, City ID: 4030556
# City Name: grand-santi, City ID: 3381538
# City Name: robertsport, City ID: 2274275
# City Name: avarua, City ID: 4035715
# City Name: berlevag, City ID: 780687
# City Name: rhyl, City ID: 2639409
# City Name: san cristobal, City ID: 3628473
# City Name: birjand, City ID: 140463
# City Name: port alfred, City ID: 964432
# City Name: cabo san lucas, City ID: 3985710
# That record does not exist, searching for next record...
# City Name: verkhnevilyuysk, City ID: 2013639
# City Name: tasiilaq, City ID: 3424607
# City Name: saint-philippe, City ID: 935215
# City Name: kaltenkirchen, City ID: 2893544
# City Name: dikson, City ID: 1507390
# City Name: hobart, City ID: 2163355
# That record does not exist, searching for next record...
# City Name: safranbolu, City ID: 740430
# City Name: porto santo, City ID: 8010683
# City Name: longyearbyen, City ID: 2729907
# City Name: biak, City ID: 1637001
# City Name: necochea, City ID: 3430443
# City Name: hermanus, City ID: 3366880
# City Name: zbarazh, City ID: 687455
# City Name: bluff, City ID: 2206939
# City Name: erenhot, City ID: 2037485
# That record does not exist, searching for next record...
# City Name: kapaa, City ID: 5848280
# City Name: padang, City ID: 1633419
# City Name: ahipara, City ID: 2194098
# City Name: esperance, City ID: 2071860
# City Name: faanui, City ID: 4034551
# City Name: punta arenas, City ID: 3874787
# City Name: omsukchan, City ID: 2122493
# City Name: puerto ayora, City ID: 3652764
# City Name: port elizabeth, City ID: 964420
# City Name: cape town, City ID: 3369157
# City Name: jamestown, City ID: 5122534
# City Name: thompson, City ID: 6165406
# City Name: yilan, City ID: 1674199
# City Name: paamiut, City ID: 3421193
# City Name: severo-kurilsk, City ID: 2121385
# City Name: bulle, City ID: 2661337
# That record does not exist, searching for next record...
# City Name: airai, City ID: 1651810
# City Name: ancud, City ID: 3899695
# City Name: serowe, City ID: 933088
# City Name: barrow, City ID: 5880054
# City Name: parana, City ID: 3841956
# City Name: victoria point, City ID: 2145214
# City Name: puerto quijarro, City ID: 3444201
# City Name: moba, City ID: 7341918
# City Name: barmer, City ID: 1276901
# City Name: sisimiut, City ID: 3419842
# City Name: san patricio, City ID: 4726521
# City Name: odessa, City ID: 698740
# That record does not exist, searching for next record...
# City Name: tianpeng, City ID: 1792916
# City Name: cherskiy, City ID: 2126199
# City Name: mana, City ID: 3381041
# City Name: albany, City ID: 5106841
# City Name: taoudenni, City ID: 2450173
# City Name: saskylakh, City ID: 2017155
# That record does not exist, searching for next record...
# City Name: arthur, City ID: 4232911
# That record does not exist, searching for next record...
# City Name: pringsewu, City ID: 1630639
# City Name: honiara, City ID: 2108502
# City Name: lebu, City ID: 3883457
# City Name: sicuani, City ID: 3928679
# City Name: zhigansk, City ID: 2012530
# That record does not exist, searching for next record...
# City Name: busselton, City ID: 2075265
# That record does not exist, searching for next record...
# That record does not exist, searching for next record...
# City Name: torbay, City ID: 6167817
# City Name: bud, City ID: 4255151
# City Name: victoria, City ID: 1819729
# City Name: te anau, City ID: 2181625
# City Name: cabra, City ID: 2520645
# City Name: chokurdakh, City ID: 2126123
# City Name: poum, City ID: 2138555
# City Name: kodiak, City ID: 5866583
# City Name: abu zabad, City ID: 380348
# City Name: tuatapere, City ID: 2180815
# City Name: shevchenkove, City ID: 694137
# City Name: taltal, City ID: 3870243
# City Name: arraial do cabo, City ID: 3471451
# City Name: san jose, City ID: 5392171
# City Name: cayenne, City ID: 3382160
# City Name: new norfolk, City ID: 2155415
# City Name: kavieng, City ID: 2094342
# City Name: butaritari, City ID: 2110227
# City Name: corovode, City ID: 783408
# City Name: nanortalik, City ID: 3421765
# City Name: mahebourg, City ID: 934322
# City Name: saldanha, City ID: 3361934
# City Name: tiksi, City ID: 2015306
# City Name: el vigia, City ID: 3641099
# City Name: ramhormoz, City ID: 118826
# That record does not exist, searching for next record...
# City Name: beira, City ID: 1052373
# City Name: krasnoselkup, City ID: 1502073
# City Name: lavrentiya, City ID: 4031637
# City Name: chifeng, City ID: 2038067
# City Name: jijiga, City ID: 333795
# City Name: vanimo, City ID: 2084442
# City Name: georgetown, City ID: 1735106
# City Name: vila velha, City ID: 3445026
# City Name: narsaq, City ID: 3421719
# City Name: kawalu, City ID: 1640902
# City Name: hilo, City ID: 5855927
# City Name: hithadhoo, City ID: 1282256
# City Name: mar del plata, City ID: 3430863
# City Name: komsomolskiy, City ID: 1513491
# City Name: hofn, City ID: 2630299
# City Name: yellowknife, City ID: 6185377
# City Name: espanola, City ID: 5467024
# City Name: naantali, City ID: 645211
# City Name: lompoc, City ID: 5367788
# City Name: bira, City ID: 2026659
# City Name: port blair, City ID: 1259385
# That record does not exist, searching for next record...
# City Name: onguday, City ID: 1496130
# City Name: byron bay, City ID: 2172880
# City Name: simplicio mendes, City ID: 3387620
# City Name: salalah, City ID: 286621
# City Name: fairbanks, City ID: 5861897
# City Name: carman, City ID: 5917275
# City Name: kysyl-syr, City ID: 2021017
# City Name: jinxiang, City ID: 1805334
# That record does not exist, searching for next record...
# City Name: jalu, City ID: 86049
# City Name: adrar, City ID: 2381972
# City Name: yunyang, City ID: 1785655
# City Name: mujiayingzi, City ID: 2035707
# City Name: norman wells, City ID: 6089245
# That record does not exist, searching for next record...
# City Name: carnarvon, City ID: 2074865
# City Name: alanya, City ID: 324190
# That record does not exist, searching for next record...
# City Name: plettenberg bay, City ID: 964712
# City Name: saint anthony, City ID: 5044290
# City Name: ballina, City ID: 2177069
# City Name: aboisso, City ID: 2293507
# City Name: griffith, City ID: 4920986
# City Name: orichi, City ID: 514966
# City Name: lata, City ID: 2738381
# City Name: hami, City ID: 1529484
# City Name: khilok, City ID: 2022463
# City Name: olinda, City ID: 3393536
# City Name: sattahip, City ID: 1606386
# City Name: hambantota, City ID: 1244926
# City Name: zhengjiatun, City ID: 2033135
# City Name: pevek, City ID: 2122090
# City Name: jaciara, City ID: 3460355
# City Name: boca do acre, City ID: 3664956
# City Name: east london, City ID: 1006984
# City Name: bathsheba, City ID: 3374083
# City Name: portland, City ID: 5746545
# City Name: hasaki, City ID: 2112802
# City Name: san policarpo, City ID: 1688696
# City Name: buta, City ID: 217570
# City Name: sitka, City ID: 5557293
# That record does not exist, searching for next record...
# City Name: merauke, City ID: 2082539
# City Name: iqaluit, City ID: 5983720
# City Name: katangli, City ID: 2122783
# City Name: baykit, City ID: 1510689
# City Name: khatanga, City ID: 2022572
# City Name: sinnamary, City ID: 3380290
# City Name: ribeira grande, City ID: 3372707
# City Name: el alto, City ID: 3697441
# City Name: talnakh, City ID: 1490256
# City Name: gjirokaster, City ID: 783148
# City Name: port macquarie, City ID: 2152659
# City Name: bealanana, City ID: 1068670
# City Name: muroto, City ID: 1856392
# City Name: gravdal, City ID: 3155152
# City Name: kruisfontein, City ID: 986717
# City Name: upernavik, City ID: 3418910
# That record does not exist, searching for next record...
# City Name: sorland, City ID: 3137469
# City Name: adelaide, City ID: 2078025
# City Name: san quintin, City ID: 3984997
# City Name: nikolskoye, City ID: 546105
# City Name: pisco, City ID: 3932145
# City Name: nemuro, City ID: 2128975
# City Name: vestmannaeyjar, City ID: 3412093
# City Name: nguruka, City ID: 151567
# City Name: qaanaaq, City ID: 3831208
# City Name: castro, City ID: 3466704
# That record does not exist, searching for next record...
# City Name: bowen, City ID: 2174444
# City Name: aykhal, City ID: 2027296
# City Name: vila, City ID: 7117100
# City Name: asau, City ID: 686090
# City Name: kathmandu, City ID: 1283240
# City Name: bayir, City ID: 304183
# City Name: mmabatho, City ID: 975436
# City Name: hinton, City ID: 5975503
# City Name: isangel, City ID: 2136825
# That record does not exist, searching for next record...
# That record does not exist, searching for next record...
# City Name: christchurch, City ID: 2192362
# City Name: barth, City ID: 2952372
# City Name: bengkulu, City ID: 1649150
# City Name: nova olinda do norte, City ID: 3393838
# City Name: mae sot, City ID: 1152188
# City Name: acurenam, City ID: 2310533
# That record does not exist, searching for next record...
# City Name: selikhino, City ID: 2017042
# City Name: gornopravdinsk, City ID: 1506268
# City Name: cap-aux-meules, City ID: 5915327
# City Name: sechura, City ID: 3691954
# City Name: hasanpur, City ID: 1270251
# City Name: ambulu, City ID: 1621313
# City Name: namatanai, City ID: 2090021
# City Name: tyumen, City ID: 1488754
# City Name: lasa, City ID: 3175096
# City Name: khorixas, City ID: 3356213
# City Name: kropotkin, City ID: 540761
# City Name: pochutla, City ID: 3517970
# City Name: kemijarvi, City ID: 653272
# That record does not exist, searching for next record...
# City Name: stephenville, City ID: 4734350
# City Name: sokolac, City ID: 3190385
# City Name: avera, City ID: 4231997
# City Name: winnemucca, City ID: 5710360
# City Name: williams lake, City ID: 6182212
# City Name: cidreira, City ID: 3466165
# City Name: port keats, City ID: 2063039
# City Name: husavik, City ID: 2629833
# City Name: podor, City ID: 2245170
# City Name: kaeo, City ID: 2189343
# City Name: lensk, City ID: 2020838
# City Name: moose factory, City ID: 6078372
# City Name: bethlehem, City ID: 3405870
# City Name: odweyne, City ID: 53372
# City Name: presidencia roque saenz pena, City ID: 3840300
# City Name: anahuac, City ID: 4013726
# City Name: roald, City ID: 3141667
# City Name: port-gentil, City ID: 2396518
# City Name: rocky mountain house, City ID: 6126749
# City Name: luderitz, City ID: 3355672
# That record does not exist, searching for next record...
# City Name: arrecife, City ID: 2521570
# City Name: saint-augustin, City ID: 6137462
# City Name: beinamar, City ID: 2435708
# City Name: codrington, City ID: 2171099
# City Name: natal, City ID: 3394023
# City Name: palencia, City ID: 3114530
# City Name: areka, City ID: 343593
# City Name: leningradskiy, City ID: 2123814
# That record does not exist, searching for next record...
# City Name: monrovia, City ID: 2274895
# City Name: walvis bay, City ID: 3359638
# City Name: baiyin, City ID: 1817240
# City Name: coquimbo, City ID: 3893629
# City Name: cockburn town, City ID: 3576994
# City Name: kahului, City ID: 5847411
# City Name: sakakah, City ID: 102527
# City Name: grindavik, City ID: 3416888
# City Name: smirnykh, City ID: 2121126
# City Name: pangnirtung, City ID: 6096551
# City Name: orlovskiy, City ID: 514796
# City Name: qaqortoq, City ID: 3420846
# City Name: catamarca, City ID: 3837702
# City Name: cap malheureux, City ID: 934649
# City Name: nouadhibou, City ID: 2377457
# City Name: lethem, City ID: 3379316
# City Name: faya, City ID: 110690
# City Name: quatre cocos, City ID: 1106643
# City Name: unisan, City ID: 1680250
# That record does not exist, searching for next record...
# City Name: haines junction, City ID: 5969025
# City Name: lumut, City ID: 1735450
# City Name: marsa matruh, City ID: 352733
# City Name: oliveira dos brejinhos, City ID: 3455903
# City Name: provideniya, City ID: 4031574
# City Name: gao, City ID: 2457161
# City Name: touros, City ID: 3386213
# That record does not exist, searching for next record...
# City Name: bacolod, City ID: 1729564
# City Name: geraldton, City ID: 2070998
# City Name: santo antonio do ica, City ID: 3662395
# That record does not exist, searching for next record...
# City Name: bilibino, City ID: 2126682
# City Name: ostersund, City ID: 2685750
# City Name: henties bay, City ID: 3356832
# City Name: alofi, City ID: 4036284
# City Name: chimore, City ID: 3920736
# City Name: elizabeth city, City ID: 4465088
# City Name: le port, City ID: 935616
# City Name: bousso, City ID: 2434584
# That record does not exist, searching for next record...
# City Name: grand gaube, City ID: 934479
# City Name: maningrida, City ID: 2067089
# City Name: baruun-urt, City ID: 2032614
# City Name: mastic beach, City ID: 5126209
# City Name: ossora, City ID: 2122389
# City Name: hovd, City ID: 1516048
# That record does not exist, searching for next record...
# City Name: santa isabel do rio negro, City ID: 3662489
# City Name: vredendal, City ID: 3359736
# City Name: sanand, City ID: 1257486
# City Name: xiuyan, City ID: 2033602
# City Name: port hardy, City ID: 6111862
# City Name: slave lake, City ID: 6149374
# City Name: bay saint louis, City ID: 4417205
# City Name: gwadar, City ID: 1177446
# City Name: cabedelo, City ID: 3404558
# City Name: neuquen, City ID: 3843123
# City Name: mogadishu, City ID: 53654
# City Name: ahuimanu, City ID: 5856516
# City Name: sosnovo-ozerskoye, City ID: 2016216
# City Name: beringovskiy, City ID: 2126710
# City Name: daigo, City ID: 2112989
# City Name: north platte, City ID: 5697939
# City Name: omboue, City ID: 2396853
# That record does not exist, searching for next record...
# City Name: pocone, City ID: 3453315
# That record does not exist, searching for next record...
# City Name: ibipeba, City ID: 3461592
# City Name: maceio, City ID: 3395981
# City Name: mandera, City ID: 187896
# City Name: college, City ID: 5859699
# City Name: clyde river, City ID: 5924351
# City Name: sur, City ID: 286245
# City Name: sorong, City ID: 1626542
# City Name: nurota, City ID: 1513087
# City Name: nhulunbuy, City ID: 2064735
# City Name: ust-barguzin, City ID: 2013986
# City Name: sangrur, City ID: 1257402
# City Name: lorengau, City ID: 2092164
# City Name: salinas, City ID: 5391295
# City Name: santiago del estero, City ID: 3835869
# City Name: palmer, City ID: 4946620
# City Name: manavalakurichi, City ID: 1263942
# City Name: usinsk, City ID: 863061
# City Name: muravlenko, City ID: 1540711
# City Name: olafsvik, City ID: 3414079
# City Name: kisesa, City ID: 156974
# City Name: vallenar, City ID: 3868633
# City Name: pulandian, City ID: 1798490
# City Name: labuhan, City ID: 8079926
# City Name: macaubas, City ID: 3458237
# City Name: vardo, City ID: 777019
# City Name: nelson bay, City ID: 2155562
# City Name: pouso alegre, City ID: 3452525
# City Name: nhamunda, City ID: 3393929
# City Name: petropavl, City ID: 1520172
# City Name: buraydah, City ID: 107304
# City Name: ucluelet, City ID: 6171633
# City Name: voi, City ID: 178522
# That record does not exist, searching for next record...
# City Name: eydhafushi, City ID: 1337606
# City Name: curaca, City ID: 3401331
# City Name: udachnyy, City ID: 2014624
# City Name: polis, City ID: 146137
# City Name: valdivia, City ID: 3868707
# City Name: kaitangata, City ID: 2208248
# City Name: bahia blanca, City ID: 3865086
# That record does not exist, searching for next record...
# City Name: amapa, City ID: 3407762
# City Name: eyl, City ID: 60019
# City Name: linxia, City ID: 1803331
# City Name: katsuura, City ID: 2112309
# City Name: koslan, City ID: 544084
# City Name: bahar, City ID: 142000
# City Name: lagoa, City ID: 3372964
# That record does not exist, searching for next record...
# City Name: jiancheng, City ID: 1806124
# That record does not exist, searching for next record...
# City Name: muros, City ID: 3115824
# City Name: roseburg, City ID: 5749352
# City Name: khudumelapye, City ID: 933633
# City Name: road town, City ID: 3577430
# City Name: chicama, City ID: 3698359
# City Name: iskateley, City ID: 866062
# City Name: bogandinskiy, City ID: 1509902
# City Name: rangapara, City ID: 1258501
# City Name: wanning, City ID: 1791779
# City Name: constantine, City ID: 2501152
# City Name: dunmanway, City ID: 2964496
# City Name: kjollefjord, City ID: 779261
# City Name: goias, City ID: 3462372
# City Name: porto walter, City ID: 3662761
# City Name: yar-sale, City ID: 1486321
# City Name: balkhash, City ID: 1525798
# City Name: yerbogachen, City ID: 2012956
# City Name: praia, City ID: 3374333
# City Name: fuyang, City ID: 1810845
# City Name: sabzevar, City ID: 118063
# City Name: sao filipe, City ID: 3374210
# City Name: turayf, City ID: 101312
# City Name: santiago, City ID: 3871336
# City Name: tezu, City ID: 1254709
# City Name: chuy, City ID: 3443061
# City Name: saurimo, City ID: 145531
# City Name: ruidoso, City ID: 5488598
# City Name: wonosobo, City ID: 1621395
# City Name: huicungo, City ID: 3696267
# City Name: urumqi, City ID: 1529102
# City Name: rye, City ID: 5134693
# City Name: lima, City ID: 3936456
# City Name: caravelas, City ID: 3466980
# City Name: buala, City ID: 2109528
# That record does not exist, searching for next record...
# City Name: samarai, City ID: 2132606
# City Name: taganak, City ID: 1684606
# City Name: nizhniy tsasuchey, City ID: 2019118
# City Name: kenai, City ID: 5866063
# City Name: wairoa, City ID: 2206808
# City Name: niamey, City ID: 2440485
# City Name: acapulco, City ID: 3533462
# City Name: salta, City ID: 3838233
# City Name: mitchell, City ID: 5229794
# City Name: tual, City ID: 1623197
# City Name: broome, City ID: 5110365
# City Name: nuuk, City ID: 3421319
# City Name: nacala, City ID: 1035025
# City Name: tevaitoa, City ID: 4033375
# City Name: butembo, City ID: 217562
# City Name: kachug, City ID: 2023333
# City Name: ondjiva, City ID: 3346821
# City Name: katherine, City ID: 2068655
# City Name: klaksvik, City ID: 2618795
# That record does not exist, searching for next record...
# City Name: luanda, City ID: 2240449
# City Name: sargatskoye, City ID: 1493004
# City Name: cangucu, City ID: 3467512
# City Name: shingu, City ID: 1847947
# City Name: qasigiannguit, City ID: 3420768
# City Name: santa ana, City ID: 5392900
# City Name: la palma, City ID: 5364022
# City Name: bereda, City ID: 3105522
# City Name: conceicao do araguaia, City ID: 3401845
# City Name: kargasok, City ID: 1504382
# City Name: murdochville, City ID: 6943820
# That record does not exist, searching for next record...
# City Name: antalaha, City ID: 1071296
# City Name: kitovo, City ID: 548040
# That record does not exist, searching for next record...
# City Name: xunchang, City ID: 1787901
# City Name: deloraine, City ID: 2169113
# City Name: sirsa, City ID: 1256052
# City Name: aketi, City ID: 220448
# City Name: axim, City ID: 2303611
# City Name: quang ngai, City ID: 1568770
# City Name: chengde, City ID: 2038087
# City Name: ziro, City ID: 1252668
# City Name: sicamous, City ID: 6147353
# City Name: lisala, City ID: 211734
# City Name: luba, City ID: 2309528
# City Name: mount gambier, City ID: 2156643
# City Name: flin flon, City ID: 5954718
# City Name: kununurra, City ID: 2068110
# City Name: mount isa, City ID: 2065594
# City Name: novo aripuana, City ID: 3663142
# City Name: kilosa, City ID: 157403
# City Name: nishihara, City ID: 1855342
# City Name: skrunda, City ID: 455520
# City Name: mindelo, City ID: 3374462
# City Name: malanje, City ID: 2239862
# City Name: sioux lookout, City ID: 6148373
# City Name: kosino, City ID: 544119
# City Name: fairfield, City ID: 4834162
# City Name: canberra, City ID: 2172517
# City Name: inuvik, City ID: 5983607
# City Name: deputatskiy, City ID: 2028164
# City Name: morristown, City ID: 4642938
# City Name: ngunguru, City ID: 2186111
# City Name: polyarnyy, City ID: 506763
# City Name: dwarka, City ID: 1272140
# That record does not exist, searching for next record...
# City Name: paithan, City ID: 1260833
# City Name: nyurba, City ID: 2018735
# City Name: sao joao dos patos, City ID: 3388615
# City Name: sao joao da barra, City ID: 3448903
# City Name: mianwali, City ID: 1170425
# City Name: xacmaz, City ID: 584717
# City Name: sargodha, City ID: 1166000
# City Name: ust-uda, City ID: 2013865
# City Name: camabatela, City ID: 2242885
# City Name: lantawan, City ID: 1715775
# City Name: alekseyevsk, City ID: 2022083
# City Name: naze, City ID: 1855540
# City Name: wenchi, City ID: 2294086
# City Name: adilabad, City ID: 1279344
# City Name: aqtobe, City ID: 610611
# City Name: biritiba-mirim, City ID: 3457001
# City Name: dzhebariki-khaya, City ID: 2024626
# That record does not exist, searching for next record...
# City Name: bardiyah, City ID: 80509
# City Name: guarapari, City ID: 3461888
# City Name: wuning, City ID: 7071576
# City Name: mahajanga, City ID: 1062663
# City Name: kalmunai, City ID: 1242110
# City Name: miandrivazo, City ID: 1059051
# City Name: chiredzi, City ID: 893485
# City Name: zhangye, City ID: 1785036
# City Name: hirara, City ID: 1862505
# City Name: vanavara, City ID: 2013727
# City Name: eureka, City ID: 5563397
# City Name: ambon, City ID: 1651531
# City Name: morant bay, City ID: 3489440
# City Name: rawson, City ID: 3839307
# City Name: sterling, City ID: 4787534
# City Name: baculin, City ID: 1729469
# City Name: kermanshah, City ID: 128226
# City Name: olavarria, City ID: 3842670
# City Name: zhoucheng, City ID: 1920772
# City Name: pryazha, City ID: 504409
# City Name: saryg-sep, City ID: 1492948
# City Name: harper, City ID: 2276492
# City Name: chuguyevka, City ID: 2025286
# City Name: bressuire, City ID: 3030302
# City Name: mtwara, City ID: 877747
# City Name: northam, City ID: 2641434
# City Name: la romana, City ID: 3500957
# That record does not exist, searching for next record...
# City Name: santa rosa, City ID: 1687894
# City Name: chitral, City ID: 1181065
# City Name: urucara, City ID: 3385670
# City Name: camopi, City ID: 3382226
# City Name: altay, City ID: 1529651
# That record does not exist, searching for next record...
# That record does not exist, searching for next record...
# City Name: seoul, City ID: 1835848
# City Name: vestmanna, City ID: 2610343
# City Name: san carlos de bariloche, City ID: 7647007
# City Name: garowe, City ID: 58933
# City Name: livingstone, City ID: 910111
# That record does not exist, searching for next record...
# City Name: flinders, City ID: 6255012
# City Name: guerrero negro, City ID: 4021858
# City Name: bandarbeyla, City ID: 64814
# City Name: lukaya, City ID: 232490
# City Name: fortuna, City ID: 5563839
# City Name: bichena, City ID: 342190
# City Name: montevideo, City ID: 3441575
# City Name: mill valley, City ID: 5373121
# That record does not exist, searching for next record...
# City Name: ilulissat, City ID: 3423146
# City Name: bushehr, City ID: 139817
# City Name: santa cruz del sur, City ID: 3537840
# City Name: hun, City ID: 2216645
# City Name: crib point, City ID: 2169995
# City Name: serro, City ID: 3447672
# That record does not exist, searching for next record...
# City Name: scottsbluff, City ID: 5699404
# City Name: shadegan, City ID: 116102
# City Name: labytnangi, City ID: 1500933
# City Name: magaria, City ID: 2441482
# City Name: arkhara, City ID: 2027487
# City Name: chemin grenier, City ID: 934614
# City Name: buchanan, City ID: 2278158
# City Name: kloulklubed, City ID: 7671223
# City Name: riachao das neves, City ID: 3451478
# City Name: port-cartier, City ID: 6111696
# City Name: terney, City ID: 2015352
# City Name: ketchikan, City ID: 5554428
# City Name: bowmore, City ID: 4486983
# City Name: aleksandrov gay, City ID: 583345
# City Name: aripuana, City ID: 3665202
# City Name: tias, City ID: 2510485
# City Name: mahibadhoo, City ID: 1337605
# City Name: sept-iles, City ID: 6144312
# City Name: kiunga, City ID: 2093846
# City Name: filimonovo, City ID: 1506834
# City Name: skoghall, City ID: 2677456
# City Name: brigantine, City ID: 4500920
# City Name: shimoda, City ID: 1852357
# City Name: phangnga, City ID: 1151464
# City Name: dapaong, City ID: 2367164
# That record does not exist, searching for next record...
# City Name: maragogi, City ID: 3395458
# City Name: takoradi, City ID: 2294915
# City Name: chulym, City ID: 1507679
# City Name: inirida, City ID: 3671450
# City Name: yulara, City ID: 6355222
# City Name: englewood, City ID: 5421250
# City Name: salihorsk, City ID: 622428
# City Name: alappuzha, City ID: 1278985
# City Name: tautira, City ID: 4033557
# City Name: sambava, City ID: 1056899
# City Name: sohbatpur, City ID: 1164660
# City Name: belmonte, City ID: 3470137
# City Name: novyy yarychiv, City ID: 698852
# City Name: blyth, City ID: 2655315
# City Name: umba, City ID: 479071
# City Name: hualmay, City ID: 3939761

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# Convert the data into a dataframe
cities_df = pd.DataFrame({"City ID": city_id_list, "City": city_name_list, "Country": country_list, "Lat": lat_list, "Lng": lng_list,
                         "Temperature": temp_list, "Humidity": humidity_list, "Clouds": clouds_list,
                         "Wind Speed": wind_speed_list})
cities_df.head()
# Out:
#    City ID          City Country      Lat       Lng  Temperature  Humidity  \
# 0  1246294         Galle      LK   6.0367   80.2170        82.26        84
# 1  1787599        Xingyi      CN  24.1877  102.8170        63.23        58
# 2  1218420         Seydi      TM  39.4816   62.9137        66.06        40
# 3  4032243         Vaini      TO -21.2000 -175.2000        77.16        61
# 4   650769  Kristinestad      FI  62.2743   21.3760        41.68        81
#
#    Clouds  Wind Speed
# 0     100       17.38
# 1     100        0.78
# 2       3        6.08
# 3      40        6.91
# 4     100       15.19

# %%
# Export to .csv file
cities_df.to_csv("C:\\Users\\Angiescomputer\\Desktop\\API_practice\\WeatherPy.ipynb", index=False, header=True)

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
x_values = cities_df["Lat"]
y_values = cities_df["Temperature"]

plt.scatter(x_values,y_values)
plt.title('Temperatures at Latitude Positions')
plt.xlabel('Latitude')
plt.ylabel('Temperature (F)')
plt.ylim(0, 100)
plt.xlim(-60, 80)
plt.minorticks_on()
plt.grid(which='major', linestyle='-')
plt.grid(which='minor', linestyle=':')
plt.tight_layout()
plt.show()
plt.savefig("Images/lat_temp.png")

# %%
x_values = cities_df["Lat"]
y_values = cities_df["Humidity"]

plt.scatter(x_values,y_values)
plt.title('Humidity at Latitude Positions')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.ylim(0, 105)
plt.xlim(-60, 80)
plt.minorticks_on()
plt.grid(which='major', linestyle='-')
plt.grid(which='minor', linestyle=':')
plt.tight_layout()
plt.show()
plt.savefig("Images/lat_humid.png")

# %%
x_values = cities_df["Lat"]
y_values = cities_df["Clouds"]

plt.scatter(x_values,y_values)
plt.title('Cloudiness at Latitude Positions')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.ylim(-5, 105)
plt.xlim(-60, 80)
plt.minorticks_on()
plt.grid(which='major', linestyle='-')
plt.grid(which='minor', linestyle=':')
plt.tight_layout()
plt.show()
plt.savefig("Images/lat_clouds.png")

# %%
x_values = cities_df["Lat"]
y_values = cities_df["Wind Speed"]

plt.scatter(x_values,y_values)
plt.title('Wind Speeds at Latitude Positions')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.ylim(0, 40)
plt.xlim(-60, 80)
plt.minorticks_on()
plt.grid(which='major', linestyle='-')
plt.grid(which='minor', linestyle=':')
plt.tight_layout()
plt.show()
plt.savefig("Images/lat_wind.png")

# %%
# Create Northern and Southern Hemisphere DataFrames
mask = cities_df['Lat'] > 0
northern_hemisphere = cities_df[mask]
southern_hemisphere = cities_df[~mask]
# Northern Hemisphere - Max Temp vs. Latitude Linear Regression
x_values = northern_hemisphere["Lat"]
y_values = northern_hemisphere["Temperature"]

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
correlation = st.pearsonr(x_values, y_values)

plt.scatter(x_values,y_values)
plt.title('Temperatures at Latitude Positions (Northern Hemisphere)')
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(10,20),fontsize=12,color="red")
plt.xlabel('Latitude')
plt.ylabel('Temperature (F)')
plt.ylim(-5, 100)
plt.xlim(0, 80)
plt.minorticks_on()
plt.grid(which='major', linestyle='-')
plt.grid(which='minor', linestyle=':')
plt.tight_layout()
plt.show()

# %%
x_values = southern_hemisphere["Lat"]
y_values = southern_hemisphere["Temperature"]

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
correlation = st.pearsonr(x_values, y_values)

plt.scatter(x_values,y_values)
plt.title('Temperatures at Latitude Positions (Southern Hemisphere)')
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-35,80),fontsize=12,color="red")
plt.xlabel('Latitude')
plt.ylabel('Temperature (F)')
plt.ylim(40, 100)
plt.xlim(0, -60)
plt.minorticks_on()
plt.grid(which='major', linestyle='-')
plt.grid(which='minor', linestyle=':')
plt.tight_layout()
plt.show()
plt.savefig("Images/sh_lat_temp_regression.png")

# %%
x_values = northern_hemisphere["Lat"]
y_values = northern_hemisphere["Humidity"]

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
correlation = st.pearsonr(x_values, y_values)

plt.scatter(x_values,y_values)
plt.title('Humidity at Latitude Positions (Northern Hemisphere)')
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(50,20),fontsize=12,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.ylim(0, 105)
plt.xlim(0, 80)
plt.minorticks_on()
plt.grid(which='major', linestyle='-')
plt.grid(which='minor', linestyle=':')
plt.tight_layout()
plt.show()
plt.savefig("Images/nh_lat_humid_regression.png")

# %%
x_values = southern_hemisphere["Lat"]
y_values = southern_hemisphere["Humidity"]

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
correlation = st.pearsonr(x_values, y_values)

plt.scatter(x_values,y_values)
plt.title('Humidity at Latitude Positions (Southern Hemisphere)')
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-35,80),fontsize=12,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.ylim(0, 105)
plt.xlim(0, -60)
plt.minorticks_on()
plt.grid(which='major', linestyle='-')
plt.grid(which='minor', linestyle=':')
#plt.tight_layout()
plt.show()
plt.savefig("Images/sh_lat_humid_regression.png")

# %%
x_values = northern_hemisphere["Lat"]
y_values = northern_hemisphere["Clouds"]

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
correlation = st.pearsonr(x_values, y_values)

plt.scatter(x_values,y_values)
plt.title('Cloudiness at Latitude Positions (Northern Hemisphere)')
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(50,20),fontsize=12,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.ylim(-5, 105)
plt.xlim(0, 80)
plt.minorticks_on()
plt.grid(which='major', linestyle='-')
plt.grid(which='minor', linestyle=':')
plt.tight_layout()
plt.show()
plt.savefig("Images/nh_lat_clouds_regression.png")

# %%
x_values = southern_hemisphere["Lat"]
y_values = southern_hemisphere["Clouds"]

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
correlation = st.pearsonr(x_values, y_values)

plt.scatter(x_values,y_values)
plt.title('Cloudiness at Latitude Positions (Southern Hemisphere)')
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-30,60),fontsize=12,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.ylim(-5, 105)
plt.xlim(0, -60)
plt.minorticks_on()
plt.grid(which='major', linestyle='-')
plt.grid(which='minor', linestyle=':')
#plt.tight_layout()
plt.show()
plt.savefig("Images/sh_lat_clouds_regression.png")

# %%
x_values = northern_hemisphere["Lat"]
y_values = northern_hemisphere["Wind Speed"]

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
correlation = st.pearsonr(x_values, y_values)

plt.scatter(x_values,y_values)
plt.title('Wind Speed at Latitude Positions (Northern Hemisphere)')
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(50,20),fontsize=12,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.ylim(0, 40)
plt.xlim(0, 80)
plt.minorticks_on()
plt.grid(which='major', linestyle='-')
plt.grid(which='minor', linestyle=':')
plt.tight_layout()
plt.show()
plt.savefig("Images/nh_lat_wind_regression.png")

# %%
x_values = southern_hemisphere["Lat"]
y_values = southern_hemisphere["Wind Speed"]

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
correlation = st.pearsonr(x_values, y_values)

plt.scatter(x_values,y_values)
plt.title('Wind Speed at Latitude Positions (Southern Hemisphere)')
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-30,20),fontsize=12,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.ylim(0, 35)
plt.xlim(0, -60)
plt.minorticks_on()
plt.grid(which='major', linestyle='-')
plt.grid(which='minor', linestyle=':')
#plt.tight_layout()
plt.show()
plt.savefig("Images/sh_lat_wind_regression.png")

# %%
#Wind Speed vs. Latitude Linear Regression
#There does seem to be a pretty strong correlation between wind sped and latitude when you look at the plots.
#  However, the linear regresion shows a much lower correlation than it appears. 
# There is still a definite correlation in both hemispheres, in that the further you are from the equator (latitude 0) 
# the higher the wind speeds are, but the slope of the regression line is much shallower than I was expecting looking at the plots.
